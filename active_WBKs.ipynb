# %% [markdown]
# # Active Projects ***JL_2 Repo***

# %% [markdown]
# ## ***ib7797sys*** __gatheress ib77 and ib97 from 10/01/2505 combines  them and plots them

# %% [markdown]
# ## ***ib97sys*** __gatheress ib97 from 4/13/2026 and plots them

# %% [markdown]
# ### 1. col_wise_import_97

# %% [markdown]
# ## ***dat_mnl sys***  ___ Journal development

# %% [markdown]
# ### dat_mnl_dct

# %% [markdown]
# ## ***root __sys development*** of root system templates

# %% [markdown]
# ### root_lbl_to_root_dct

# %% [markdown]
# ## ***ib_97 sys***  ___ 1st example useing a root system templates

# %% [markdown]
# # ***dat_mnl_dct*** __import dat_mnl tbl to dct
